# %% [markdown]
# ### vgg19随机初始化训练

# %%
# !python main.py -p 100
# Out:
# => creating model 'vgg19'
# Epoch: [0][0/14256]	Time 2.131 (2.131)	Data 0.420 (0.420)	Loss 3.2490 (3.2490)	Prec@1 0.000 (0.000)	Prec@5 25.000 (25.000)
# Epoch: [0][100/14256]	Time 0.162 (0.173)	Data 0.000 (0.005)	Loss 2.5113 (3.0593)	Prec@1 25.000 (12.129)	Prec@5 75.000 (41.089)
# Epoch: [0][200/14256]	Time 0.132 (0.163)	Data 0.000 (0.003)	Loss 2.9751 (3.0135)	Prec@1 25.000 (12.065)	Prec@5 50.000 (44.030)
# Epoch: [0][300/14256]	Time 0.151 (0.159)	Data 0.000 (0.002)	Loss 2.6177 (2.9614)	Prec@1 0.000 (12.542)	Prec@5 75.000 (47.757)
# Epoch: [0][400/14256]	Time 0.162 (0.158)	Data 0.000 (0.002)	Loss 3.0540 (2.9491)	Prec@1 0.000 (13.155)	Prec@5 50.000 (48.815)
# Epoch: [0][500/14256]	Time 0.143 (0.157)	Data 0.000 (0.002)	Loss 2.9934 (2.9455)	Prec@1 0.000 (13.473)	Prec@5 25.000 (49.102)
# Epoch: [0][600/14256]	Time 0.147 (0.156)	Data 0.000 (0.002)	Loss 2.1821 (2.9361)	Prec@1 0.000 (13.270)	Prec@5 100.000 (49.459)
# ...

# %%
# !python main.py
# Out:
# arch = vgg19
# workers = 4
# epochs = 90
# start_epoch = 0
# batch_size = 4
# lr = 0.001
# momentum = 0.9
# weight_decay = 0.0001
# print_freq = 10
# resume =
# evaluate = False
# pretrained = False
# world_size = 1
# dist_url = tcp://224.66.41.62:23456
# dist_backend = gloo
# seed = None
# gpu = None
# => creating model 'vgg19'
# Epoch: [0][0/25]	Time 2.550 (2.550)	Data 0.333 (0.333)	Loss 3.2703 (3.2703)	Prec@1 0.000 (0.000)	Prec@5 25.000 (25.000)
# Epoch: [0][10/25]	Time 0.149 (0.364)	Data 0.000 (0.034)	Loss 3.2615 (3.2559)	Prec@1 0.000 (4.545)	Prec@5 25.000 (27.273)
# Epoch: [0][20/25]	Time 0.147 (0.265)	Data 0.000 (0.024)	Loss 3.2451 (3.1878)	Prec@1 25.000 (8.333)	Prec@5 50.000 (35.714)
# Test: [0/25]	Time 0.665 (0.665)	Loss 2.3301 (2.3301)	Prec@1 0.000 (0.000)	Prec@5 100.000 (100.000)
# Test: [10/25]	Time 0.032 (0.130)	Loss 2.3481 (2.3376)	Prec@1 0.000 (0.000)	Prec@5 100.000 (100.000)
# ...

# %% [markdown]
# ### vgg19 pretrained初始化训练
# 现象：loss过大(loss=nan)
# 结果：无结果

# %%
# !python main.py --learning-rate 0.01 --print-freq 100 --pretrained
# Out:
# arch = vgg19
# workers = 4
# epochs = 90
# start_epoch = 0
# batch_size = 4
# lr = 0.01
# momentum = 0.9
# weight_decay = 0.0001
# print_freq = 100
# resume =
# evaluate = False
# pretrained = True
# world_size = 1
# dist_url = tcp://224.66.41.62:23456
# dist_backend = gloo
# seed = None
# gpu = None
# => using pre-trained model 'vgg19'
# Epoch: [0][0/14256]	Time 1.936 (1.936)	Data 0.341 (0.341)	Loss 3.5078 (3.5078)	Prec@1 0.000 (0.000)	Prec@5 0.000 (0.000)
# Epoch: [0][100/14256]	Time 0.148 (0.168)	Data 0.000 (0.004)	Loss 3.0673 (34919773176155804.0000)	Prec@1 0.000 (15.099)	Prec@5 50.000 (50.000)
# Epoch: [0][200/14256]	Time 0.153 (0.161)	Data 0.000 (0.003)	Loss 2.8416 (17546751695481276.0000)	Prec@1 0.000 (13.682)	Prec@5 50.000 (51.617)
# Epoch: [0][300/14256]	Time 0.147 (0.159)	Data 0.000 (0.002)	Loss 3.5829 (11717266082364572.0000)	Prec@1 0.000 (12.957)	Prec@5 0.000 (52.159)
# ...

# %%
# !python main.py --learning-rate 0.01 --print-freq 100 --pretrained
# Out:
# arch = vgg19
# workers = 4
# epochs = 90
# start_epoch = 0
# batch_size = 4
# lr = 0.01
# momentum = 0.9
# weight_decay = 0.0001
# print_freq = 100
# resume =
# evaluate = False
# pretrained = True
# world_size = 1
# dist_url = tcp://224.66.41.62:23456
# dist_backend = gloo
# seed = None
# gpu = None
# => using pre-trained model 'vgg19'
# Epoch: [0][0/14256]	Time 1.188 (1.188)	Data 0.246 (0.246)	Loss 3.6300 (3.6300)	Prec@1 0.000 (0.000)	Prec@5 0.000 (0.000)
# Epoch: [0][100/14256]	Time 0.072 (0.086)	Data 0.000 (0.007)	Loss nan (nan)	Prec@1 0.000 (2.970)	Prec@5 0.000 (12.129)
# Epoch: [0][200/14256]	Time 0.072 (0.089)	Data 0.000 (0.015)	Loss nan (nan)	Prec@1 0.000 (2.985)	Prec@5 0.000 (13.308)
# ^C
# Process Process-3:
# Process Process-1:
# Traceback (most recent call last):
#   File "/home/yuelu/anaconda2/envs/py36/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# ...

# %%
# !python main.py --learning-rate 0.01 --print-freq 100
# Out:
# arch = vgg19
# workers = 4
# epochs = 90
# start_epoch = 0
# batch_size = 4
# lr = 0.01
# momentum = 0.9
# weight_decay = 0.0001
# print_freq = 100
# resume =
# evaluate = False
# pretrained = False
# world_size = 1
# dist_url = tcp://224.66.41.62:23456
# dist_backend = gloo
# seed = None
# gpu = None
# => creating model 'vgg19'
# Epoch: [0][0/14256]	Time 1.380 (1.380)	Data 0.359 (0.359)	Loss 3.3143 (3.3143)	Prec@1 0.000 (0.000)	Prec@5 0.000 (0.000)
# Epoch: [0][100/14256]	Time 0.073 (0.086)	Data 0.000 (0.004)	Loss 2.2243 (3.0742)	Prec@1 50.000 (13.614)	Prec@5 75.000 (52.970)
# Epoch: [0][200/14256]	Time 0.072 (0.083)	Data 0.000 (0.006)	Loss 2.5573 (3.0250)	Prec@1 50.000 (13.184)	Prec@5 75.000 (51.741)
# Epoch: [0][300/14256]	Time 0.074 (0.081)	Data 0.000 (0.006)	Loss 2.6198 (2.9669)	Prec@1 25.000 (13.123)	Prec@5 75.000 (52.076)
# Epoch: [0][400/14256]	Time 0.072 (0.079)	Data 0.000 (0.005)	Loss 2.3900 (2.9334)	Prec@1 0.000 (14.152)	Prec@5 75.000 (52.930)
# ...

# %% [markdown]
# ### vgg19随机初始化训练

# %%
# !python main.py --learning-rate 0.01  --checkpoint_dir checkpoint0723
# Out:
# arch = vgg19
# workers = 4
# epochs = 90
# start_epoch = 0
# batch_size = 4
# lr = 0.01
# momentum = 0.9
# weight_decay = 0.0001
# print_freq = 100
# resume =
# evaluate = False
# pretrained = False
# world_size = 1
# dist_url = tcp://224.66.41.62:23456
# dist_backend = gloo
# seed = None
# gpu = 0
# checkpoint_dir = checkpoint0723
# => creating model 'vgg19'
# Epoch: [0][0/14256]	Time 1.492 (1.492)	Data 0.633 (0.633)	Loss 3.3000 (3.3000)	Prec@1 25.000 (25.000)	Prec@5 25.000 (25.000)
# Epoch: [0][100/14256]	Time 0.072 (0.129)	Data 0.000 (0.059)	Loss 2.7638 (2.9902)	Prec@1 25.000 (15.099)	Prec@5 50.000 (48.020)
# Epoch: [0][200/14256]	Time 0.231 (0.123)	Data 0.200 (0.059)	Loss 2.7900 (2.9253)	Prec@1 50.000 (16.542)	Prec@5 50.000 (50.373)
# Epoch: [0][300/14256]	Time 0.073 (0.123)	Data 0.000 (0.059)	Loss 2.7694 (2.9210)	Prec@1 0.000 (15.282)	Prec@5 75.000 (52.076)
# ...
