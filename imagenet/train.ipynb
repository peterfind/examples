# %% [markdown]
# ### 24日 vgg19 随机初始化 27类风格分类 训练 0-23epochs

# %%
# !python main.py --learning-rate 0.001  --checkpoint_dir checkpoint0724 --print-freq 1000
# Out:
# arch = vgg19
# workers = 4
# epochs = 90
# start_epoch = 0
# batch_size = 4
# lr = 0.001
# momentum = 0.9
# weight_decay = 0.0001
# print_freq = 1000
# resume =
# evaluate = False
# pretrained = False
# world_size = 1
# dist_url = tcp://224.66.41.62:23456
# dist_backend = gloo
# seed = None
# gpu = 0
# checkpoint_dir = checkpoint0724
# class_type = Style
# => creating model 'vgg19'
# Mon Jul 23 23:23:19 2018
# Epoch: [0][0/14256]	Time 1.434 (1.434)	Data 0.564 (0.564)	Loss 3.2844 (3.2844)	Prec@1 0.000 (0.000)	Prec@5 25.000 (25.000)
# Epoch: [0][1000/14256]	Time 0.078 (0.137)	Data 0.000 (0.075)	Loss 2.9910 (2.9097)	Prec@1 25.000 (15.260)	Prec@5 25.000 (51.499)
# Epoch: [0][2000/14256]	Time 0.073 (0.151)	Data 0.000 (0.089)	Loss 2.9291 (2.8738)	Prec@1 25.000 (15.717)	Prec@5 25.000 (52.574)
# Epoch: [0][3000/14256]	Time 0.079 (0.158)	Data 0.000 (0.096)	Loss 2.5745 (2.8634)	Prec@1 25.000 (15.078)	Prec@5 75.000 (52.866)
# ...

# %% [markdown]
# ### 去除数目过少的类别，训练Style

# %% [markdown]
# ### 24日晚->25日早 vgg19 pretrained 固定前几层 18类风格分类 训练 0-21epochs

# %%
# !CUDA_VISIBLE_DEVICES=1 python main.py --learning-rate 0.001  --checkpoint_dir checkpoint0725_style18 --print-freq 1000 --class_type Style18 --arch vgg19 --pretrained
# Out:
# arch = vgg19
# workers = 4
# epochs = 90
# start_epoch = 0
# batch_size = 4
# lr = 0.001
# momentum = 0.9
# weight_decay = 0.0001
# print_freq = 1000
# resume =
# evaluate = False
# pretrained = True
# world_size = 1
# dist_url = tcp://224.66.41.62:23456
# dist_backend = gloo
# seed = None
# gpu = 0
# checkpoint_dir = checkpoint0725_style18
# class_type = Style18
# param_watch_freq = 100
# => using pre-trained model 'vgg19'
# Fix some layer in pretrained model.
# Wed Jul 25 00:47:48 2018
# Epoch: [0][0/13330]	Time 1.839 (1.839)	Data 1.224 (1.224)	Loss 2.8860 (2.8860)	Prec@1 25.000 (25.000)	Prec@5 50.000 (50.000)
# Epoch: [0][1000/13330]	Time 0.068 (0.074)	Data 0.000 (0.015)	Loss 2.1480 (2.2976)	Prec@1 25.000 (25.974)	Prec@5 75.000 (71.129)
# Epoch: [0][2000/13330]	Time 0.068 (0.073)	Data 0.000 (0.013)	Loss 1.6544 (2.1997)	Prec@1 25.000 (27.724)	Prec@5 75.000 (74.113)
# ...

# %% [markdown]
# ### 25日中午->25日下午 vgg19 pretrained 固定前几层 18类风格分类 训练 21-26epochs

# %%
# !CUDA_VISIBLE_DEVICES=1 python main.py --learning-rate 0.001  --checkpoint_dir checkpoint0725_style18 --print-freq 1000 --class_type Style18 --arch vgg19 --pretrained \
--resume checkpoint0725_style18/checkpoint.pth.tar --tensorboard_log_dir log_0725_style18
# Out:
# arch = vgg19
# workers = 4
# epochs = 90
# start_epoch = 0
# batch_size = 4
# lr = 0.001
# momentum = 0.9
# weight_decay = 0.0001
# print_freq = 1000
# resume = checkpoint0725_style18/checkpoint.pth.tar
# evaluate = False
# pretrained = True
# world_size = 1
# dist_url = tcp://224.66.41.62:23456
# dist_backend = gloo
# seed = None
# gpu = 0
# checkpoint_dir = checkpoint0725_style18
# class_type = Style18
# tensorboard_print_freq = 100
# tensorboard_log_dir = log_0725_style18
# => using pre-trained model 'vgg19'
# Fix some layer in pretrained model.
# => loading checkpoint 'checkpoint0725_style18/checkpoint.pth.tar'
# => loaded checkpoint 'checkpoint0725_style18/checkpoint.pth.tar' (epoch 22)
# Wed Jul 25 11:36:11 2018
# Epoch: [22][0/13330]	Time 2.864 (2.864)	Data 2.282 (2.282)	Loss 0.2210 (0.2210)	Prec@1 75.000 (75.000)	Prec@5 100.000 (100.000)
# Epoch: [22][1000/13330]	Time 0.119 (0.083)	Data 0.092 (0.022)	Loss 0.7231 (1.1906)	Prec@1 75.000 (58.442)	Prec@5 100.000 (94.680)
# ...

# %% [markdown]
# ### 25日下午 vgg19 pretrained 固定前几层 18类风格分类 训练 27-28epochs

# %%
# !CUDA_VISIBLE_DEVICES=1 python main.py --learning-rate 0.001  --checkpoint_dir ./checkpoint0725_style18 --print-freq 1000 --class_type Style18 --arch vgg19 --pretrained \
--resume checkpoint0725_style18/checkpoint.pth.tar --tensorboard_log_dir ./checkpoint0725_style18/log
# Out:
# arch = vgg19
# workers = 4
# epochs = 90
# start_epoch = 0
# batch_size = 4
# lr = 0.001
# momentum = 0.9
# weight_decay = 0.0001
# print_freq = 1000
# resume = checkpoint0725_style18/checkpoint.pth.tar
# evaluate = False
# pretrained = True
# world_size = 1
# dist_url = tcp://224.66.41.62:23456
# dist_backend = gloo
# seed = None
# gpu = 0
# checkpoint_dir = ./checkpoint0725_style18
# class_type = Style18
# tensorboard_print_freq = 100
# tensorboard_log_dir = ./checkpoint0725_style18/log
# => using pre-trained model 'vgg19'
# Fix some layer in pretrained model.
# => loading checkpoint 'checkpoint0725_style18/checkpoint.pth.tar'
# => loaded checkpoint 'checkpoint0725_style18/checkpoint.pth.tar' (epoch 27)
# Wed Jul 25 14:00:30 2018
# Epoch: [27][0/13330]	Time 2.750 (2.750)	Data 2.145 (2.145)	Loss 2.2421 (2.2421)	Prec@1 50.000 (50.000)	Prec@5 75.000 (75.000)
# ...

# %% [markdown]
# ### 25日下午 vgg19 pretrained 固定前几层 18类风格分类 训练 29-37epochs

# %%
# !CUDA_VISIBLE_DEVICES=1 python main.py --learning-rate 0.001  --checkpoint_dir ./checkpoint0725_style18 --print-freq 1000 --class_type Style18 --arch vgg19 --pretrained \
--resume checkpoint0725_style18/checkpoint.pth.tar --tensorboard_log_dir ./checkpoint0725_style18/log
# Out:
# arch = vgg19
# workers = 4
# epochs = 90
# start_epoch = 0
# batch_size = 4
# lr = 0.001
# momentum = 0.9
# weight_decay = 0.0001
# print_freq = 1000
# resume = checkpoint0725_style18/checkpoint.pth.tar
# evaluate = False
# pretrained = True
# world_size = 1
# dist_url = tcp://224.66.41.62:23456
# dist_backend = gloo
# seed = None
# gpu = 0
# checkpoint_dir = ./checkpoint0725_style18
# class_type = Style18
# tensorboard_print_freq = 100
# tensorboard_log_dir = ./checkpoint0725_style18/log
# => using pre-trained model 'vgg19'
# Fix some layer in pretrained model.
# => loading checkpoint 'checkpoint0725_style18/checkpoint.pth.tar'
# => loaded checkpoint 'checkpoint0725_style18/checkpoint.pth.tar' (epoch 29)
# Wed Jul 25 15:29:41 2018
# Epoch: [29][0/13330]	Time 2.783 (2.783)	Data 2.206 (2.206)	Loss 1.4989 (1.4989)	Prec@1 50.000 (50.000)	Prec@5 100.000 (100.000)
# ...

# %% [markdown]
# ### 25日下午 vgg19 pretrained 固定前几层 18类风格分类 训练 38-?epochs 不调整学习率 训练所有层

# %%
# !CUDA_VISIBLE_DEVICES=1 python main.py --learning-rate 0.001  --checkpoint_dir ./checkpoint0725_style18 --print-freq 1000 --class_type Style18 --arch vgg19 \
--resume checkpoint0725_style18/checkpoint_epoch37.pth.tar --tensorboard_log_dir ./checkpoint0725_style18/log/4
# Out:
# arch = vgg19
# workers = 4
# epochs = 90
# start_epoch = 0
# batch_size = 4
# lr = 0.001
# momentum = 0.9
# weight_decay = 0.0001
# print_freq = 1000
# resume = checkpoint0725_style18/checkpoint_epoch37.pth.tar
# evaluate = False
# pretrained = False
# world_size = 1
# dist_url = tcp://224.66.41.62:23456
# dist_backend = gloo
# seed = None
# gpu = 0
# checkpoint_dir = ./checkpoint0725_style18
# class_type = Style18
# tensorboard_print_freq = 100
# tensorboard_log_dir = ./checkpoint0725_style18/log/4
# dispaly_images = False
# => creating model 'vgg19'
# => loading checkpoint 'checkpoint0725_style18/checkpoint_epoch37.pth.tar'
# => loaded checkpoint 'checkpoint0725_style18/checkpoint_epoch37.pth.tar' (epoch 38)
# Thu Jul 26 00:08:58 2018
# Epoch: [38][0/13330]	Time 2.816 (2.816)	Data 1.978 (1.978)	Loss 0.2522 (0.2522)	Prec@1 (100.000)	Prec@5 (100.000)
