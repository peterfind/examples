# %% [markdown]
# ### vgg19随机初始化训练

# %%
# !python main.py -p 100
# Out:
# => creating model 'vgg19'
# Epoch: [0][0/14256]	Time 2.131 (2.131)	Data 0.420 (0.420)	Loss 3.2490 (3.2490)	Prec@1 0.000 (0.000)	Prec@5 25.000 (25.000)
# Epoch: [0][100/14256]	Time 0.162 (0.173)	Data 0.000 (0.005)	Loss 2.5113 (3.0593)	Prec@1 25.000 (12.129)	Prec@5 75.000 (41.089)
# Epoch: [0][200/14256]	Time 0.132 (0.163)	Data 0.000 (0.003)	Loss 2.9751 (3.0135)	Prec@1 25.000 (12.065)	Prec@5 50.000 (44.030)
# Epoch: [0][300/14256]	Time 0.151 (0.159)	Data 0.000 (0.002)	Loss 2.6177 (2.9614)	Prec@1 0.000 (12.542)	Prec@5 75.000 (47.757)
# Epoch: [0][400/14256]	Time 0.162 (0.158)	Data 0.000 (0.002)	Loss 3.0540 (2.9491)	Prec@1 0.000 (13.155)	Prec@5 50.000 (48.815)
# Epoch: [0][500/14256]	Time 0.143 (0.157)	Data 0.000 (0.002)	Loss 2.9934 (2.9455)	Prec@1 0.000 (13.473)	Prec@5 25.000 (49.102)
# Epoch: [0][600/14256]	Time 0.147 (0.156)	Data 0.000 (0.002)	Loss 2.1821 (2.9361)	Prec@1 0.000 (13.270)	Prec@5 100.000 (49.459)
# ...
