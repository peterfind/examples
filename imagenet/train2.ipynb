# %% [markdown]
# ### 文件位置'/media/gisdom/2TB_2/luyue/examples/imagenet'

# %% [markdown]
# ### 24日 vgg19 随机初始化 按Artist分类 训练 0-44epochs

# %%
# !CUDA_VISIBLE_DEVICES=0 python main.py --learning-rate 0.001  --checkpoint_dir checkpoint0724_artist --print-freq 1000 --class_type Artist
# Out:
# arch = vgg19
# workers = 4
# epochs = 90
# start_epoch = 0
# batch_size = 4
# lr = 0.001
# momentum = 0.9
# weight_decay = 0.0001
# print_freq = 1000
# resume =
# evaluate = False
# pretrained = False
# world_size = 1
# dist_url = tcp://224.66.41.62:23456
# dist_backend = gloo
# seed = None
# gpu = 0
# checkpoint_dir = checkpoint0724_artist
# class_type = Artist
# => creating model 'vgg19'
# Mon Jul 23 23:26:35 2018
# Epoch: [0][0/3337]	Time 1.555 (1.555)	Data 0.664 (0.664)	Loss 3.1201 (3.1201)	Prec@1 0.000 (0.000)	Prec@5 50.000 (50.000)
# Epoch: [0][1000/3337]	Time 0.082 (0.178)	Data 0.000 (0.118)	Loss 3.1181 (3.0724)	Prec@1 25.000 (10.165)	Prec@5 25.000 (36.014)
# Epoch: [0][2000/3337]	Time 0.080 (0.161)	Data 0.000 (0.099)	Loss 2.9074 (3.0541)	Prec@1 25.000 (9.845)	Prec@5 25.000 (37.506)
# Epoch: [0][3000/3337]	Time 0.088 (0.150)	Data 0.000 (0.082)	Loss 3.1966 (3.0536)	Prec@1 0.000 (9.747)	Prec@5 0.000 (37.596)
# ...

# %% [markdown]
# ### 24日 vgg19 随机初始化 按Artist分类 训练 45-87epochs 训练集精度54.4% 验证集精度 56.6%

# %%
# !python main.py --learning-rate 0.001  --checkpoint_dir ./checkpoint0724_artist --print-freq 1000 --class_type Artist --resume ./checkpoint0724_artist/checkpoint.pth.tar
# Out:
# arch = vgg19
# workers = 4
# epochs = 90
# start_epoch = 0
# batch_size = 4
# lr = 0.001
# momentum = 0.9
# weight_decay = 0.0001
# print_freq = 1000
# resume = ./checkpoint0724_artist/checkpoint.pth.tar
# evaluate = False
# pretrained = False
# world_size = 1
# dist_url = tcp://224.66.41.62:23456
# dist_backend = gloo
# seed = None
# gpu = 0
# checkpoint_dir = checkpoint0724_artist
# class_type = Artist
# => creating model 'vgg19'
# => loading checkpoint './checkpoint0724_artist/checkpoint.pth.tar'
# => loaded checkpoint './checkpoint0724_artist/checkpoint.pth.tar' (epoch 45)
# Tue Jul 24 11:25:41 2018
# Epoch: [45][0/3337]	Time 1.564 (1.564)	Data 0.736 (0.736)	Loss 1.0920 (1.0920)	Prec@1 75.000 (75.000)	Prec@5 100.000 (100.000)
# Epoch: [45][1000/3337]	Time 0.072 (0.116)	Data 0.000 (0.055)	Loss 0.9342 (1.7018)	Prec@1 75.000 (49.226)	Prec@5 100.000 (82.318)
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python main.py --learning-rate 0.001  --checkpoint_dir ./checkpoint0724_artist --print-freq 100 --class_type Artist \
--tensorboard_log_dir ./checkpoint0724_artist/log/1 --resume ./checkpoint0724_artist/checkpoint_epoch87.pth.tar --evaluate
# Out:
# arch = vgg19
# workers = 4
# epochs = 90
# start_epoch = 0
# batch_size = 4
# lr = 0.001
# momentum = 0.9
# weight_decay = 0.0001
# print_freq = 100
# resume = ./checkpoint0724_artist/checkpoint_epoch87.pth.tar
# evaluate = True
# pretrained = False
# world_size = 1
# dist_url = tcp://224.66.41.62:23456
# dist_backend = gloo
# seed = None
# gpu = 0
# checkpoint_dir = ./checkpoint0724_artist
# class_type = Artist
# tensorboard_print_freq = 100
# tensorboard_log_dir = ./checkpoint0724_artist/log/1
# dispaly_images = False
# => creating model 'vgg19'
# => loading checkpoint './checkpoint0724_artist/checkpoint_epoch87.pth.tar'
# => loaded checkpoint './checkpoint0724_artist/checkpoint_epoch87.pth.tar' (epoch 90)
# Thu Jul 26 11:57:00 2018
# Validate on validationSet
# Test: [0/90]	Time 9.428 (9.428)	Loss (1.3095)	Prec@1 (56.250)	Prec@5 (90.625)
# Test: [89/90]	Time 0.483 (0.567)	Loss (1.5452)	Prec@1 (53.172)	Prec@5 (84.858)
# Thu Jul 26 11:57:52 2018
# Thu Jul 26 11:57:52 2018
# ...

# %% [markdown]
# ### 25日中午->25日晚上 vgg11 随机初始化 18类风格分类 训练 0-29epochs

# %%
# !CUDA_VISIBLE_DEVICES=0 python main.py --learning-rate 0.001  --checkpoint_dir checkpoint0725_style18_vgg11 --print-freq 1000 --class_type Style18 --arch vgg11 \
--tensorboard_log_dir log_0725_style18_vgg11
# Out:
# arch = vgg11
# workers = 4
# epochs = 90
# start_epoch = 0
# batch_size = 4
# lr = 0.001
# momentum = 0.9
# weight_decay = 0.0001
# print_freq = 1000
# resume =
# evaluate = False
# pretrained = False
# world_size = 1
# dist_url = tcp://224.66.41.62:23456
# dist_backend = gloo
# seed = None
# gpu = 0
# checkpoint_dir = checkpoint0725_style18_vgg11
# class_type = Style18
# tensorboard_print_freq = 100
# tensorboard_log_dir = log_0725_style18_vgg11
# => creating model 'vgg11'
# Wed Jul 25 11:37:55 2018
# Epoch: [0][0/13330]	Time 3.039 (3.039)	Data 2.403 (2.403)	Loss 2.8963 (2.8963)	Prec@1 0.000 (0.000)	Prec@5 0.000 (0.000)
# Epoch: [0][1000/13330]	Time 0.054 (0.079)	Data 0.016 (0.032)	Loss 2.8589 (2.6699)	Prec@1 50.000 (16.384)	Prec@5 50.000 (56.419)
# Epoch: [0][2000/13330]	Time 0.052 (0.076)	Data 0.000 (0.028)	Loss 3.0616 (2.6480)	Prec@1 25.000 (16.504)	Prec@5 25.000 (57.084)
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python main.py --learning-rate 0.001  --checkpoint_dir ./checkpoint0725_style18_vgg11 --print-freq 1000 --class_type Style18 --arch vgg11 \
--tensorboard_log_dir ./checkpoint0725_style18_vgg11/log/2 --resume ./checkpoint0725_style18_vgg11/checkpoint.pth.tar
# Out:
# arch = vgg11
# workers = 4
# epochs = 90
# start_epoch = 0
# batch_size = 4
# lr = 0.001
# momentum = 0.9
# weight_decay = 0.0001
# print_freq = 1000
# resume = ./checkpoint0725_style18_vgg11/checkpoint.pth.tar
# evaluate = False
# pretrained = False
# world_size = 1
# dist_url = tcp://224.66.41.62:23456
# dist_backend = gloo
# seed = None
# gpu = 0
# checkpoint_dir = ./checkpoint0725_style18_vgg11
# class_type = Style18
# tensorboard_print_freq = 100
# tensorboard_log_dir = ./checkpoint0725_style18_vgg11/log/2
# dispaly_images = False
# => creating model 'vgg11'
# => loading checkpoint './checkpoint0725_style18_vgg11/checkpoint.pth.tar'
# => loaded checkpoint './checkpoint0725_style18_vgg11/checkpoint.pth.tar' (epoch 30)
# Wed Jul 25 23:47:42 2018
# Epoch: [30][0/13330]	Time 2.443 (2.443)	Data 1.919 (1.919)	Loss 2.1620 (2.1620)	Prec@1 (0.000)	Prec@5 (100.000)
# Epoch: [30][1000/13330]	Time 0.053 (0.073)	Data 0.000 (0.024)	Loss 2.2579 (1.5060)	Prec@1 (48.127)	Prec@5 (89.810)
# ...
